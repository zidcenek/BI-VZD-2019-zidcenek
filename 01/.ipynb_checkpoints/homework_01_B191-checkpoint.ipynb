# %% [markdown]
# # Úkol č. 1 - vizualizace dat a web scraping (do 20. října)
#
#   * V rámci tohoto úkolu musíte stáhnout dat z webu (tzv. _web scraping_, velmi základní) a následně data zpracovat a vizualizovat.
#   * Cílem bude stáhnout data ze serveru https://www.volby.cz týkající se voleb do zastupitelstva Vámi vybraného (většího) města, uložit tato data v tabulkovém formátu a pak vymyslet vizualizace a zobrazení dat, které umožní orientaci v těchto datech a zvýrazní zajímavé informace a zobrazit přehledně časový vývoj různých veličin.
#
# > **Úkoly jsou zadány tak, aby Vám daly prostor pro invenci. Vymyslet _jak přesně_ budete úkol řešit, je důležitou součástí zadání a originalita či nápaditost bude také hodnocena!**
#
# ## Výběr zdroje dat
#
# Vyberte si větší město, které má zastupitelstvo druhu 3 (Zastupitelstvo statutárního města) a strojově stáhněte informace o stranách a kandidátkách z následujících let:
#  * [2002](https://www.volby.cz/pls/kv2002/kv12?xjazyk=CZ&xid=0), [2006](https://www.volby.cz/pls/kv2006/kv12?xjazyk=CZ&xid=0), [2010](https://www.volby.cz/pls/kv2010/kv12?xjazyk=CZ&xid=0), [2014](https://www.volby.cz/pls/kv2014/kv12?xjazyk=CZ&xid=0) a [2018](https://www.volby.cz/pls/kv2018/kv12?xjazyk=CZ&xid=0).
#
#
# ## Pokyny k vypracování
#
# **Základní body zadání**, za jejichž (poctivé) vypracování získáte **8 bodů**:
#   * Strojově stáhněte data pro vybrané město a uložte je všechny do (asi dvou) přehledných tabulek ve formátu _csv_.
#   * Data musí obsahovat _alespoň_ toto:
#     * Vývoj výsledků (v procentech i počtu hlasů) pro jednotlivé strany v jednotlivých letech.
#     * Seznam všech kandidátů všech stran v jednotlivých letech, u kandidáta by mělo být zaznamenáno: jméno, věk v době voleb, navrhující strana, politická příslušnost, volební zisk (procento i počet hlasů), pořadí na kandidátce, pořadí zvolení, jestli získal mandát (tyto informace získáte souhrnně ve _jmenných seznamech_).
#   * V druhé části Vašeho Jupyter notebooku pracujte s těmito tabulkami načtenými z _csv_ souboru (aby opravující nemusel spouštět stahování z webu).
#   * Tabulky ve formátu _csv_ také odevzdejte.
#   * S využitím vybraných nástrojů zpracujte data a vymyslete vizualizace a grafy, aby bylo vidět následující:
#     * Časový vývoj (po rocích voleb) počtu kandidujících stran i lidí a to celkově i po jednotlivých stranách (ve volbách, kterých se daná strana účastnila).
#     * Věkovou strukturu kandidátů celkově i za jednotlivé strany a vývoj této struktury během jednotlivých voleb.
#     * Časový vývoj volební účasti a volebních výsledků jednotlivých stran.
#     * Časový vývoj podílu kandidujících s titulem a bez titulu.
#
# **Další body zadání** za případné další body (můžete si vybrat, maximum bodů za úkol je každopádně 12 bodů):
#   * (až +2 body) U titulů se pokuste rozlišit i různé stupně vzdělání: bakalářský, magisterský, doktorský a vyšší, vojenská hodnost atp. Zkuste odhadnout i podíl žen na kandidátkách.
#   * (až +4 body) Pokuste se u jednotlivých kandidátů zjistit, zda kandidovali ve více volbách. Najděte 10 nejpilnějších kandidátů a vypište jejich volební zisky a za jaké strany kandidovali.
#   * (až +2 body) Najděte nějaký balíček, který Vám dovolí do Vašeho notebooku zavést interaktivní prvky, např. si vyberete v select-boxu stranu a Váš notebook zobrazí grafy pouze pro ni atp.
#
# ## Poznámky k odevzdání
#
#   * Řiďte se pokyny ze stránky https://courses.fit.cvut.cz/BI-VZD/homeworks/index.html.
#   * Odevzdejte nejen Jupyter Notebook, ale i _csv_ soubor(y) se staženými daty.
#   * Opravující Vám může umožnit úkol dodělat či opravit a získat tak další body. První verze je ale důležitá a bude-li odbytá, budete za to penalizováni.

# %%
import numpy as np
import pandas as pd
import sklearn as skit
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import copy

# %%
party_data = []
people_data = []
summary_data = []

years = [2018, 2014, 2010, 2006]

for year in years:
    '''
        celkové načtení dat a základní úprava hlaviček
    '''
    url = 'https://www.volby.cz/pls/kv' + str(year) + '/kv1111?xjazyk=CZ&xid=1&xdz=3&xnumnuts=5103&xobec=563889&xstat=0&xvyber=0'
    dfs = pd.read_html(url,flavor='html5lib')
    dfs[1].columns = dfs[1].columns.to_frame()[1]
    dfs[1]["Rok"] = np.full(len(dfs[1]), year)
    party_data.append(dfs[1])
    summary_data.append(dfs[0])
    url = 'https://www.volby.cz/pls/kv' + str(year) + '/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
    dfs = pd.read_html(url,flavor='html5lib')
    dfs[0].columns = dfs[0].columns.to_frame()[1]
    dfs[0]["v %"] = dfs[0]["v %"] / 100
    dfs[0]["Rok"] = np.full(len(dfs[0]), year)
    people_data.append(dfs[0])
    
# data pro strany roku 2002
url = 'http://www.volby.cz/pls/kv2002/kv1211?xjazyk=CZ&xid=1&xv=1&xdz=3&xnumnuts=5103'
party_data_2002 = pd.read_html(url, displayed_only=False)
summary_data.append(party_data_2002[0])

# data z jmennych seznamu roku 2002
url = 'http://www.volby.cz/pls/kv2002/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
people_data_2002 = pd.read_html(url, displayed_only=False)
people_data_2002[0].columns = people_data_2002[0].columns.to_frame()[1]
people_data_2002[0]["Rok"] = np.full(len(people_data_2002[0]), 2002)

# %%
# uprava hlavicek dat
summary = copy.deepcopy(summary_data)
for i in range(4):
    summary[i].columns = summary[i].columns.to_frame()[1]
    summary[i] = summary[i].drop(columns=["v %", "Početvolebníchobvodů"])
    summary[i]["Rok"] = np.full(len(summary[i]), years[i])
    summary[i]["Volebníúčast v %"] = summary[i]["Volebníúčast v %"]/100 
summary[4].columns = summary[4].columns.to_frame()[1]
summary[4] = summary[4].drop(columns=["celkem", "zvolená"])
summary[4]["Rok"] = np.full(len(summary[4]), 2002)
summary[4].columns = summary[0].columns
summary = pd.concat(summary)

# %%
# Řešení titulů pro roky 2006 - 2018
# Rozpoznávaé tituly
titles = ["Bc.", "BcA.", "Ing.", "Ing. arch.", "MUDr.", "MVDr.", "Mgr.", "MgA.", "JUDr.", "PhDr.", "RNDr.", "PharmDr.", "ThLic.", "ThDr.", "Ph.D.", "Ph.D.", "Th.D.", "CSc.", "DrSc.", "doc.", "prof."]

for df in people_data:
    cols = list(df)
    cols.insert(4, "Tituly")
    df["Tituly"] = np.nan
    df.columns = cols
    buffer = []
    name_frame = []
    title_frame = []
    for index, name in enumerate(cols):
        tmp = copy.deepcopy(df[name])
        if index > 4: # posun sloupců doleva
            df[name] = copy.deepcopy(buffer)
        buffer = copy.deepcopy(tmp)
    for index, row in df.iterrows():
        arr = row["příjmení, jméno, tituly"].split()
        title = ""
        new_name = ""
        if len(arr) < 3:
            title_frame.append("")
            name_frame.append(row["příjmení, jméno, tituly"])
            continue
        for name in arr:
            if name in titles: 
                title = title + " " + name
            else:
                if new_name == "":
                    new_name = name
                else:
                    new_name = new_name + " " + name
        title_frame.append(title)
        name_frame.append(new_name)
    df["Tituly"] = title_frame
    df["příjmení, jméno, tituly"] = name_frame

# %%
display(people_data_2002[0].columns)
display(people_data[3].columns)
# Out:
# Index(['Kandidátnílistina', 'Kandidátnílistina.1', 'Poř.číslo',
#        'Příjmení, jméno', 'Tituly', 'Věk', 'Navrh.strana', 'Polit.přísl.',
#        'abs.', 'v %', 'Pořadí', 'Mandát', 'Rok'],
#       dtype='object', name=1)
# Index(['číslo', 'název', 'poř.číslo', 'příjmení, jméno, tituly', 'Tituly',
#        'věk', 'Navrhujícístrana', 'Politickápříslušnost', 'abs.', 'v %',
#        'Pořadízvolení/náhradníka', 'Mandát', 'Rok'],
#       dtype='object')

# %%
# převedení hlaviček na stejné
people_data_2002[0].columns = people_data[0].columns
people_data.append(people_data_2002[0])

# %%
df = copy.deepcopy(people_data_2002[0])
name_frame = []
for index, row in df.iterrows():
    arr = row["příjmení, jméno, tituly"].split()
    new_name = ""
    for name in arr:
        if new_name == "":
            new_name = name
        else:
            new_name = new_name + " " + name
    name_frame.append(new_name)
df["příjmení, jméno, tituly"] = name_frame
people_data_2002[0]["příjmení, jméno, tituly"] = name_frame

# %%
party_data_2002[0].columns = party_data_2002[0].columns.to_frame()[1]
party_data_2002[1].columns = party_data_2002[1].columns.to_frame()[1]
party_data_2002[1]["Rok"] = np.full(len(party_data_2002[1]), 2002)

# %%
for index, df in enumerate(party_data): 
    party_data[index] = party_data[index].drop(columns = ["číslo", "Početkandidátů", "Přepočtenýzákladdle počtukandidátů", "Podílyhlasů"])
    party_data[index]["v %"] = party_data[index]["v %"]/100

# %%
display(party_data_2002[1].columns)
display(party_data[0].columns)
# Out:
# Index(['Volební strana', 'abs.', 'v %', 'abs.', 'v %', 'Rok'], dtype='object', name=1)
# Index(['název', 'abs.', 'v %', 'Přepočtené %platných hlasů', 'Početmandátů',
#        'Rok'],
#       dtype='object', name=1)

# %%
# převedení hlaviček na stejné pro jednotlivé strany
party_data_2002[1].columns = party_data[0].columns
party_data_2002[1].columns

party_data_2002[1]['Přepočtené %platných hlasů'], party_data_2002[1]['Početmandátů'] = party_data_2002[1]['Početmandátů'], party_data_2002[1]['Přepočtené %platných hlasů']
party_data_2002[1]['Přepočtené %platných hlasů'] = np.nan
party_data.append(party_data_2002[1])

# %%
# finální spojení dat z jednotlivých let a přejmenování odlišných názvů stran
party_result = pd.concat(party_data)
party_result = party_result.replace(regex=[r'Komunistická str.Čech a Moravy'], value='Komunistická strana Čech a Moravy')
party_result = party_result.replace(regex=[r'Česká str.sociálně demokrat.'], value='Česká strana sociálně demokratická')
party_result = party_result.drop(columns = ["Přepočtené %platných hlasů"])
#party_result.groupby(["název"]).size()

# %%
# finální spojení dat ze jmenných seznamů
people_result = pd.concat(people_data)

# %%
# uložení dat do csv souborů
pd.DataFrame(party_result).to_csv("party_data.csv")
pd.DataFrame(people_result).to_csv("people_data.csv")
pd.DataFrame(summary).to_csv("summary.csv")

# %%
# kontrola funkčnosti zpětného načtení dat
data1 = pd.read_csv('party_data.csv')
data2 = pd.read_csv('people_data.csv', na_values=["", "-"])

# %% [markdown]
# ### Používáne funkce v následující části

# %%
# staženo z https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 0),
                    textcoords="offset points",
                    ha='center', va='bottom')

# %%
# zdroj: https://stackoverflow.com/questions/51676506/bar-chart-with-label-name-and-value-on-top-in-pandas
def autolabel2(ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for p in ax.patches:
        ax.annotate('{:d}'.format(int(float(p.get_height()))), (p.get_x(), p.get_height()))

# %%
def getYears():
    """vrácení všech relevantních let"""
    return [2018, 2014, 2010, 2006, 2002]

# %% [markdown]
# ### Zobrazení počtu kandidátů, kandidujících stran atd.

# %%
years = [2018, 2014, 2010, 2006, 2002]
data = pd.read_csv('people_data.csv', na_values=["", "-"])
candidating_parties = {}
fig, ax = plt.subplots()
for year in years: 
    df = data.loc[data.Rok == year]
    df = df.groupby(["Rok", "název"]).size()
    candidating_parties[year] = len(df[year])
rect = ax.bar(range(len(candidating_parties)), list(candidating_parties.values()), align='center')
plt.xticks(range(len(candidating_parties)), list(candidating_parties.keys()))
plt.title("Počet kandidujících stran v jednotlivých letech")
### Pokuste se u jednotlivých kandidátů zjistit, zda kandidovali ve více volbách. Najděte 10 nejpilnějších kandidátů a vypište jejich volební zisky a za jaké strany kandidovali.### Pokuste se u jednotlivých kandidátů zjistit, zda kandidovali ve více volbách. Najděte 10 nejpilnějších kandidátů a vypište jejich volební zisky a za jaké strany kandidovali.autolabel(rect)
plt.show()

# %%
years = [2018, 2014, 2010, 2006, 2002]
data = pd.read_csv('people_data.csv', na_values=["", "-"])
candidates = {}
fig, ax = plt.subplots()
for year in years: 
    df = data.loc[data.Rok == year]
    df = df.groupby(["Rok"]).size()
    candidates[year] = df[year]
rect = ax.bar(range(len(candidates)), list(candidates.values()), align='center', label = "asdas")
plt.xticks(range(len(candidates)), list(candidates.keys()))
autolabel(rect)
fig.tight_layout()
plt.title("Počet celkového počtu kandidátů v jednotlivých letech")
plt.show()

# %%
years = [2018, 2014, 2010, 2006, 2002]
data = pd.read_csv('people_data.csv', na_values=["", "-"])
for year in years: 
    df = data.loc[data.Rok == year]
    df = df.groupby(["Rok", "název"]).size()
    df.plot(kind='bar')
    plt.title("Počet kandidátů v roce " + str(year) + " za jednotlivé strany")
    plt.show()

# %% [markdown]
# ### Statistiky týkající se titulů

# %%
data = pd.read_csv('people_data.csv', na_values=["", "-"])
data["Tituly"] = pd.isna(data2["Tituly"])
data = data.groupby(["Tituly", "Rok"]).size()
bar_width = 0.3
opacity = 0.8
index = np.arange(5)

fig, ax = plt.subplots()


rects1 = ax.bar(index, data[0], bar_width,
alpha=opacity,
color='r',
label='bez titulu')

rects2 = ax.bar(index + bar_width, data[1], bar_width,
alpha=opacity,
color='g',
label='s titulem')

autolabel(rects1)
autolabel(rects2)
plt.xticks(index + bar_width/2, range(2002, 2020, 4))
plt.legend()
plt.title("Poměr kandidátů s titulem a bez titulu v jednotlivých letech")
plt.show()

# %%
data = pd.read_csv('people_data.csv', na_values=["", "-"])
data["Tituly"] = pd.isna(data2["Tituly"])
for year in getYears():
    df = data.loc[data.Rok == year]
    df = df.groupby(["název", "Tituly"]).size()
    fig, ax = plt.subplots()
    stats = {}
    for i in range(0, len(df) - 1, 2):
        stats[df.keys()[i][0]] = df[i]/(df[i] + df[i+1]) # stats[nazev strany] = procento lidi s titulem
    rect = ax.bar(range(len(stats)), list(stats.values()), align='center', label = "asdas")
    plt.xticks(range(len(stats)), list(stats.keys()), rotation="vertical")
    plt.title("Procento kandidátů s titulem v roce " + str(year) + " za jednotlivé strany")
    plt.show()

# %% [markdown]
# ### Statistiky týkající se věku kandidátů

# %%
years = [2018, 2014, 2010, 2006, 2002]
data = pd.read_csv('people_data.csv', na_values=["", "-"])
for year in years: 
    fig, ax = plt.subplots()
    df = data.loc[data.Rok == year]
    df = df.groupby(["Rok", "název"]).mean()
    df = df["věk"]
    ax = df.plot(kind='bar')
    autolabel2(ax)
    plt.title("Zaokrouhlený průměrný věk kandidujících stran v roce " + str(year))
    plt.show()

# %%
data = pd.read_csv('people_data.csv', na_values=["", "-"])
df = data.groupby(["název"]).size()
df.keys()
for party in df.keys(): 
    df = data.loc[data.název == party]
    df = df.groupby(["název", "Rok"]).mean()
    df = df["věk"]
    if len(df) > 2:
        ax = df.plot(kind='bar')
        plt.title("Vývoj věkového průměru strany: '" + party + "' v jednotlivých letech")
        autolabel2(ax)
        plt.show()

# %% [markdown]
# ### Statistiky týkající se celkových výsledků voleb a volební účasti

# %%
data = pd.read_csv('summary.csv', na_values=["", "-"])
summ = {}
data = data["Volebníúčast v %"]
fig, ax = plt.subplots()

for i in range(len(getYears())):
    summ[getYears()[i]] = data[i]
rect = ax.bar(range(len(summ)), list(summ.values()), align='center')
plt.xticks(range(len(summ)), list(summ.keys()))
autolabel(rect)
fig.tight_layout()
plt.title("Volební účast v jednotlivých letech")
plt.show()

# %%
data = pd.read_csv('party_data.csv', na_values=["", "-"])

for year in getYears(): 
    df = data.loc[data.Rok == year][['název','v %']]
    df.plot(kind="bar")
    plt.xticks(range(len(list(df["název"]))), list(df["název"]))
    plt.title("Procentuální vývoj voleb v roce " + str(year))
    plt.show()

# %% [markdown]
# ### Pokuste se u jednotlivých kandidátů zjistit, zda kandidovali ve více volbách. Najděte 10 nejpilnějších kandidátů a vypište jejich volební zisky a za jaké strany kandidovali.

# %%
# nejpilnější kandidáti
data = pd.read_csv('people_data.csv', na_values=["", "-"])
df = data.groupby(["příjmení, jméno, tituly"]).size()
df = df.sort_values(ascending=False)
df = df.loc[df == 4]
for i in range(len(df)): # ti, kterí kandidovali ve všech sledovaných letech
    name, cnt = df.keys()[i], df[i]
    frame = data[data["příjmení, jméno, tituly"].str.contains(name)]
    frame = frame.drop(columns=["Unnamed: 0", "číslo", "poř.číslo"]).sort_values(by="Rok")
    display(frame)
# Out:
#                   název příjmení, jméno, tituly Tituly  věk Navrhujícístrana  \
# 1709    Strana zelených        Tachovská Zuzana   Mgr.   36               SZ
# 1416  Změna pro Liberec        Tachovská Zuzana   Mgr.   40               SZ
# 978   Změna pro Liberec        Tachovská Zuzana   Mgr.   44            Změna
# 383   Změna pro Liberec        Tachovská Zuzana   Mgr.   48            Změna
#
#      Politickápříslušnost   abs.   v %  Pořadízvolení/náhradníka Mandát   Rok
# 1709                BEZPP  3 472  2.71                       4.0    NaN  2006
# 1416                   SZ  7 074  2.81                       1.0    NaN  2010
# 978                 Změna  7 025  2.64                       8.0      *  2014
# 383                 Změna  4 269  2.70                       2.0    NaN  2018
#                                název příjmení, jméno, tituly Tituly  věk  \
# 2096  Unie svobody-Demokratická unie        Petrovský Ondřej    NaN   21
# 1329               Změna pro Liberec        Petrovský Ondřej   Mgr.   29
# 850                Změna pro Liberec        Petrovský Ondřej   Mgr.   33
# 288                Změna pro Liberec        Petrovský Ondřej   Mgr.   37
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2096           US-DEU               US-DEU  1 290  2.38
# 1329               NK                BEZPP  7 095  2.82
# 850            Zelení               Zelení  7 230  2.72
# 288            Zelení               Zelení  4 472  2.83
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2096                      22.0    NaN  2002
# 1329                       3.0    NaN  2010
# 850                        7.0      *  2014
# 288                        4.0      *  2018
#                              název příjmení, jméno, tituly Tituly  věk  \
# 2257  Občanská demokratická strana       Vojtíšek Vladimír   Ing.   43
# 1737  Občanská demokratická strana       Vojtíšek Vladimír   Ing.   47
# 1442  Občanská demokratická strana       Vojtíšek Vladimír   Ing.   51
# 426        Unie pro sport a zdraví       Vojtíšek Vladimír   Ing.   59
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2257              ODS                  ODS  7 154  2.61
# 1737              ODS                  ODS  8 587  2.63
# 1442              ODS                  ODS  5 584  2.58
# 426               USZ                BEZPP  1 003  1.98
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2257                       7.0    NaN  2002
# 1737                      12.0      *  2006
# 1442                       7.0    NaN  2010
# 426                        NaN    NaN  2018
#                              název příjmení, jméno, tituly Tituly  věk  \
# 1914  Občanská demokratická strana        Jarošová Naděžda    NaN   46
# 1549  Občanská demokratická strana        Jarošová Naděžda    NaN   50
# 1166  Občanská demokratická strana        Jarošová Naděžda    NaN   54
# 154   Občanská demokratická strana        Jarošová Naděžda    NaN   62
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1914              ODS                  ODS  7 277  2.66
# 1549              ODS                  ODS  8 471  2.59
# 1166              ODS                  ODS  5 620  2.60
# 154               ODS                  ODS  2 556  2.56
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1914                       8.0      *  2002
# 1549                       7.0      *  2006
# 1166                       1.0    NaN  2010
# 154                       10.0    NaN  2018
#                              název příjmení, jméno, tituly Tituly  věk  \
# 1826  Česká str.sociálně demokrat.              Dušek Petr    NaN   32
# 1501  Česká str.sociálně demokrat.              Dušek Petr    NaN   36
# 1105  Česká str.sociálně demokrat.              Dušek Petr    NaN   40
# 562   Česká str.sociálně demokrat.              Dušek Petr    NaN   44
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1826             ČSSD                 ČSSD  3 999  2.57
# 1501             ČSSD                 ČSSD  3 913  2.42
# 1105             ČSSD                 ČSSD  5 139  2.50
# 562              ČSSD                 ČSSD  2 515  2.45
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1826                      12.0    NaN  2002
# 1501                      26.0    NaN  2006
# 1105                      20.0    NaN  2010
# 562                       25.0    NaN  2014
#                                název příjmení, jméno, tituly Tituly  věk  \
# 2173  Komunistická str.Čech a Moravy         Svoboda Antonín   Ing.   42
# 1687  Komunistická str.Čech a Moravy         Svoboda Antonín   Ing.   46
# 1381  Komunistická str.Čech a Moravy         Svoboda Antonín   Ing.   50
# 930               Strana Práv Občanů         Svoboda Antonín    NaN   63
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2173             KSČM                 KSČM  2 828  2.67
# 1687             KSČM                BEZPP  2 768  2.79
# 1381             KSČM                 KSČM  2 347  2.78
# 930               SPO                BEZPP     46  2.28
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2173                       3.0    NaN  2002
# 1687                       1.0    NaN  2006
# 1381                       2.0    NaN  2010
# 930                        NaN    NaN  2014
#                         název příjmení, jméno, tituly Tituly  věk  \
# 2102  Unie pro sport a zdraví         Piskačová Petra    NaN   26
# 1653  Unie pro sport a zdraví         Piskačová Petra    NaN   30
# 1333  Unie pro sport a zdraví         Piskačová Petra    NaN   34
# 291   Unie pro sport a zdraví         Piskačová Petra    NaN   42
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2102              USZ                BEZPP  1 821  2.57
# 1653              USZ                BEZPP  2 451  2.39
# 1333              USZ                BEZPP  1 984  2.34
# 291               USZ                BEZPP  1 295  2.55
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2102                      16.0    NaN  2002
# 1653                      18.0    NaN  2006
# 1333                      20.0    NaN  2010
# 291                        NaN    NaN  2018
#                               název příjmení, jméno, tituly Tituly  věk  \
# 1656                SOS pro Liberec            Prade Robert    NaN   34
# 1341                Liberec občanům            Prade Robert    NaN   38
# 862   Starostové pro Liberecký kraj            Prade Robert    NaN   42
# 304   Starostové pro Liberecký kraj            Prade Robert    NaN   46
#
#      Navrhujícístrana Politickápříslušnost    abs.   v %  \
# 1656              SOS                BEZPP   6 485  2.73
# 1341               NK                BEZPP   3 594  2.20
# 862               SLK                BEZPP   4 732  2.73
# 304               SLK                BEZPP  10 037  2.63
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1656                       9.0    NaN  2006
# 1341                      29.0    NaN  2010
# 862                        2.0    NaN  2014
# 304                       11.0      *  2018
#                               název příjmení, jméno, tituly Tituly  věk  \
# 1700                SOS pro Liberec               Šolc Jiří    NaN   28
# 1398                Liberec občanům               Šolc Jiří    Bc.   32
# 957   Starostové pro Liberecký kraj               Šolc Jiří   Mgr.   36
# 371   Starostové pro Liberecký kraj               Šolc Jiří   Mgr.   40
#
#      Navrhujícístrana Politickápříslušnost    abs.   v %  \
# 1700         Suveren.                BEZPP   7 179  3.03
# 1398              SLK                  SLK   6 519  3.99
# 957               SLK                  SLK   5 410  3.12
# 371               SLK                BEZPP  10 837  2.83
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1700                       3.0      *  2006
# 1398                       1.0      *  2010
# 957                        1.0      *  2014
# 371                        2.0      *  2018
#                               název příjmení, jméno, tituly  Tituly  věk  \
# 2138   Str.pro otevřenou společnost        Rozkovcová Jitka   MUDr.   62
# 1670                SOS pro Liberec        Rozkovcová Jitka   MUDr.   66
# 1360                Liberec občanům        Rozkovcová Jitka   MUDr.   70
# 885   Starostové pro Liberecký kraj        Rozkovcová Jitka   MUDr.   74
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2138              SOS                  SOS  2 983  3.04
# 1670              SOS                  SOS  6 478  2.73
# 1360               NK                BEZPP  4 369  2.67
# 885               SLK                BEZPP  4 269  2.46
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2138                       1.0    NaN  2002
# 1670                      17.0    NaN  2006
# 1360                      11.0    NaN  2010
# 885                       23.0    NaN  2014
#                               název příjmení, jméno, tituly Tituly  věk  \
# 2118   Str.pro otevřenou společnost             Princ Tomáš   Ing.   53
# 1658                SOS pro Liberec             Princ Tomáš   Ing.   57
# 1342                Liberec občanům             Princ Tomáš   Ing.   61
# 865   Starostové pro Liberecký kraj             Princ Tomáš   Ing.   65
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2118              SOS                BEZPP  2 685  2.74
# 1658              SOS                  SOS  6 440  2.71
# 1342               NK                BEZPP  4 458  2.73
# 865               SLK                BEZPP  4 501  2.60
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2118                      13.0    NaN  2002
# 1658                       7.0    NaN  2006
# 1342                       6.0    NaN  2010
# 865                        8.0    NaN  2014
#                              název příjmení, jméno, tituly Tituly  věk  \
# 1895  Česká str.sociálně demokrat.         Hruša František   Ing.   53
# 1536  Česká str.sociálně demokrat.         Hruša František   Ing.   57
# 1155  Česká str.sociálně demokrat.         Hruša František   Ing.   61
# 133   Česká str.sociálně demokrat.         Hruša František   Ing.   69
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1895             ČSSD                 ČSSD  4 658  2.99
# 1536             ČSSD                 ČSSD  4 464  2.76
# 1155             ČSSD                 ČSSD  5 620  2.74
# 133              ČSSD                 ČSSD    537  2.13
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1895                       3.0      *  2002
# 1536                       3.0      *  2006
# 1155                       6.0      *  2010
# 133                        NaN    NaN  2018
#                                název příjmení, jméno, tituly Tituly  věk  \
# 2227  Komunistická str.Čech a Moravy        Ullrich Jindřich    NaN   55
# 1721  Komunistická str.Čech a Moravy        Ullrich Jindřich    NaN   59
# 1423  Komunistická str.Čech a Moravy        Ullrich Jindřich    NaN   63
# 985   Komunistická str.Čech a Moravy        Ullrich Jindřich    NaN   67
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2227             KSČM                 KSČM  2 613  2.46
# 1721             KSČM                 KSČM  2 498  2.52
# 1423             KSČM                 KSČM  1 804  2.14
# 985              KSČM                 KSČM  1 346  2.30
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2227                      25.0    NaN  2002
# 1721                      19.0    NaN  2006
# 1423                      36.0    NaN  2010
# 985                       35.0    NaN  2014
#                                název příjmení, jméno, tituly Tituly  věk  \
# 2123   Křesť.demokr.unie-Čs.str.lid.               Puhal Jan   Ing.   52
# 1663  NEZ.DEMOKRATÉ(předs.V.Železný)               Puhal Jan   Ing.   56
# 874                         ANO 2011               Puhal Jan   Ing.   64
# 312                         ANO 2011               Puhal Jan   Ing.   68
#
#      Navrhujícístrana Politickápříslušnost   abs.    v %  \
# 2123          KDU-ČSL                BEZPP    928   2.61
# 1663          NEZ/DEM              NEZ/DEM    247  12.80
# 874               ANO                BEZPP  4 786   2.54
# 312               ANO                  ANO  6 565   2.58
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2123                       NaN    NaN  2002
# 1663                       NaN    NaN  2006
# 874                       16.0    NaN  2014
# 312                        4.0    NaN  2018
#                                název příjmení, jméno, tituly Tituly  věk  \
# 2228  Komunistická str.Čech a Moravy           Ullrich Milan    NaN   52
# 1722  Komunistická str.Čech a Moravy           Ullrich Milan    NaN   55
# 1424  Komunistická str.Čech a Moravy           Ullrich Milan    NaN   59
# 986   Komunistická str.Čech a Moravy           Ullrich Milan    NaN   63
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2228             KSČM                BEZPP  2 564  2.42
# 1722             KSČM                 KSČM  2 484  2.51
# 1424             KSČM                 KSČM  2 010  2.38
# 986              KSČM                 KSČM  1 423  2.44
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2228                      28.0    NaN  2002
# 1722                      22.0    NaN  2006
# 1424                      31.0    NaN  2010
# 986                       30.0    NaN  2014
#                              název příjmení, jméno, tituly Tituly  věk  \
# 1647  Česká str.sociálně demokrat.          Pěnička Zbyněk    NaN   55
# 1323  Česká str.sociálně demokrat.          Pěnička Zbyněk    NaN   59
# 840   Česká str.sociálně demokrat.          Pěnička Zbyněk    NaN   63
# 281   Česká str.sociálně demokrat.          Pěnička Zbyněk    NaN   67
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1647             ČSSD                 ČSSD  4 271  2.64
# 1323             ČSSD                 ČSSD  5 161  2.51
# 840              ČSSD                 ČSSD  2 548  2.48
# 281              ČSSD                 ČSSD    602  2.38
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1647                       3.0    NaN  2006
# 1323                      22.0    NaN  2010
# 840                       22.0    NaN  2014
# 281                        NaN    NaN  2018
#                               název příjmení, jméno, tituly Tituly  věk  \
# 2200  Křesť.demokr.unie-Čs.str.lid.             Šourek Petr   Ing.   57
# 1702                SOS pro Liberec             Šourek Petr   Ing.   61
# 1403                Liberec občanům             Šourek Petr   Ing.   65
# 962             KDU-ČSL a nezávislí             Šourek Petr   Ing.   69
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2200          KDU-ČSL              KDU-ČSL    913  2.57
# 1702          KDU-ČSL              KDU-ČSL  6 709  2.83
# 1403          KDU-ČSL              KDU-ČSL  4 305  2.63
# 962           KDU-ČSL              KDU-ČSL    569  2.37
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2200                       NaN    NaN  2002
# 1702                       5.0      *  2006
# 1403                       3.0    NaN  2010
# 962                        NaN    NaN  2014
#                              název příjmení, jméno, tituly Tituly  věk  \
# 1808  Občanská demokratická strana         Červinka Ondřej    Bc.   25
# 1490  Občanská demokratická strana         Červinka Ondřej   Ing.   29
# 1089  Občanská demokratická strana         Červinka Ondřej   Ing.   33
# 534   Občanská demokratická strana         Červinka Ondřej   Ing.   37
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1808              ODS                  ODS  7 566  2.77
# 1490              ODS                  ODS  8 763  2.68
# 1089              ODS                  ODS  5 881  2.72
# 534               ODS                  ODS  1 762  3.34
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1808                       5.0      *  2002
# 1490                       2.0      *  2006
# 1089                       5.0      *  2010
# 534                        1.0      *  2014
#                               název příjmení, jméno, tituly Tituly  věk  \
# 2027  Křesť.demokr.unie-Čs.str.lid.               Marek Jan  JUDr.   53
# 1276                Liberec občanům               Marek Jan   Mgr.   31
# 791   Starostové pro Liberecký kraj               Marek Jan   Mgr.   35
# 244   Starostové pro Liberecký kraj               Marek Jan   Mgr.   39
#
#      Navrhujícístrana Politickápříslušnost    abs.   v %  \
# 2027          KDU-ČSL              KDU-ČSL   1 379  3.88
# 1276          KDU-ČSL                BEZPP   3 803  2.32
# 791               SLK                BEZPP   4 634  2.67
# 244               SLK                BEZPP  10 161  2.66
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2027                       NaN    NaN  2002
# 1276                      23.0    NaN  2010
# 791                        8.0      *  2014
# 244                        9.0      *  2018
#                               název příjmení, jméno, tituly Tituly  věk  \
# 1801   Str.pro otevřenou společnost         Cvrček Vladimír   Mgr.   63
# 1085                Liberec občanům         Cvrček Vladimír   Mgr.   71
# 518   Starostové pro Liberecký kraj         Cvrček Vladimír   Mgr.   75
# 44    Starostové pro Liberecký kraj         Cvrček Vladimír   Mgr.   79
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1801              SOS                BEZPP  2 307  2.35
# 1085               NK                BEZPP  3 730  2.28
# 518               SLK                BEZPP  4 412  2.55
# 44                SLK                BEZPP  9 286  2.43
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1801                      21.0    NaN  2002
# 1085                      25.0    NaN  2010
# 518                       11.0    NaN  2014
# 44                        17.0    NaN  2018
#                                název příjmení, jméno, tituly Tituly  věk  \
# 1766  Komunistická str.Čech a Moravy         Bělohlávek Jiří    NaN   52
# 1471  Komunistická str.Čech a Moravy         Bělohlávek Jiří    NaN   56
# 1056  Komunistická str.Čech a Moravy         Bělohlávek Jiří    NaN   60
# 17    Komunistická str.Čech a Moravy         Bělohlávek Jiří    NaN   68
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1766             KSČM                 KSČM  2 971  2.80
# 1471             KSČM                 KSČM  2 490  2.51
# 1056             KSČM                 KSČM  2 228  2.64
# 17               KSČM                 KSČM    917  2.54
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1766                       4.0      *  2002
# 1471                      26.0    NaN  2006
# 1056                       8.0    NaN  2010
# 17                         NaN    NaN  2018
#                         název příjmení, jméno, tituly  Tituly  věk  \
# 1989                NEZÁVISLÍ             Krobot Petr   MVDr.   58
# 1591  Unie pro sport a zdraví             Krobot Petr   MVDr.   62
# 1234  Unie pro sport a zdraví             Krobot Petr   MVDr.   66
# 744        PRO Sport a Zdraví             Krobot Petr   MVDr.   70
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1989              NEZ                  NEZ  2 526  4.97
# 1591              USZ                  USZ  2 864  2.79
# 1234              USZ                  USZ  2 251  2.65
# 744            PRO ZS                  USZ    941  2.70
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1989                       4.0    NaN  2002
# 1591                      17.0    NaN  2006
# 1234                      24.0    NaN  2010
# 744                        NaN    NaN  2014
#                              název příjmení, jméno, tituly Tituly  věk  \
# 1990  Česká str.sociálně demokrat.            Kroll Martin    Bc.   37
# 1592  Česká str.sociálně demokrat.            Kroll Martin    Bc.   41
# 1235  Česká str.sociálně demokrat.            Kroll Martin   Mgr.   45
# 745   Česká str.sociálně demokrat.            Kroll Martin   Mgr.   49
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1990             ČSSD                 ČSSD  4 140  2.66
# 1592             ČSSD                 ČSSD  4 269  2.64
# 1235             ČSSD                 ČSSD  5 154  2.51
# 745              ČSSD                 ČSSD  2 649  2.58
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1990                       8.0    NaN  2002
# 1592                      13.0    NaN  2006
# 1235                      23.0    NaN  2010
# 745                       18.0    NaN  2014
#                            název příjmení, jméno, tituly Tituly  věk  \
# 1599             SOS pro Liberec        Kvapil Vítězslav    NaN   59
# 1247  SOS - Liberecký zastupitel        Kvapil Vítězslav    NaN   63
# 758                     ANO 2011        Kvapil Vítězslav    NaN   67
# 218                     ANO 2011        Kvapil Vítězslav    NaN   71
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1599              SOS                  SOS  5 838  2.46
# 1247              SOS                  SOS  1 241  2.85
# 758               ANO                BEZPP  4 562  2.42
# 218               ANO                  ANO  6 605  2.60
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1599                      19.0    NaN  2006
# 1247                       NaN    NaN  2010
# 758                       24.0    NaN  2014
# 218                       10.0      *  2018
#                                název příjmení, jméno, tituly Tituly  věk  \
# 1759  Demokratická regionální strana              Bartoš Jan    NaN   58
# 1051  Demokratická regionální strana              Bartoš Jan    NaN   66
# 472           Úsvit přímé demokracie              Bartoš Jan    NaN   70
# 7     Svob.a př.dem.-T.Okamura (SPD)              Bartoš Jan    NaN   74
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1759              DRS                  DRS  1 336  2.21
# 1051              DRS                  DRS    976  2.05
# 472             Úsvit                BEZPP    401  2.76
# 7                 SPD                  SPD  1 424  2.61
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1759                      24.0    NaN  2002
# 1051                       NaN    NaN  2010
# 472                        NaN    NaN  2014
# 7                          NaN    NaN  2018
#                               název příjmení, jméno, tituly      Tituly  věk  \
# 1489    SNK ED a nezávislí společně              Černý Petr         NaN   32
# 1088                   Věci veřejné              Černý Petr         Bc.   36
# 528   Nový směr-společná kandidátka              Černý Petr   Ing. Mgr.   40
# 53                    Liberec Plus+              Černý Petr   Ing. Mgr.   44
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1489           SNK ED               SNK ED  2 329  3.22
# 1088               VV                   VV  4 104  4.64
# 528               NOS                  NOS  1 544  5.46
# 53                NOS                  NOS    814  4.37
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1489                       3.0    NaN  2006
# 1088                       1.0      *  2010
# 528                        NaN    NaN  2014
# 53                         NaN    NaN  2018
#                                název příjmení, jméno, tituly Tituly  věk  \
# 1081    Strana Práv Občanů ZEMANOVCI             Cihlář Jiří   Ing.   54
# 1082    Strana Práv Občanů ZEMANOVCI             Cihlář Jiří    NaN   28
# 515               Strana Práv Občanů             Cihlář Jiří   Ing.   58
# 42    Komunistická str.Čech a Moravy             Cihlář Jiří   Ing.   62
#
#      Navrhujícístrana Politickápříslušnost abs.   v %  \
# 1081             SPOZ                 SPOZ  564  6.04
# 1082             SPOZ                 SPOZ  246  2.63
# 515               SPO                  SPO  114  5.65
# 42               KSČM                 KSČM  957  2.65
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1081                       NaN    NaN  2010
# 1082                       NaN    NaN  2010
# 515                        NaN    NaN  2014
# 42                         NaN    NaN  2018
#                         název příjmení, jméno, tituly Tituly  věk  \
# 1756  Unie pro sport a zdraví      Bahníková Štefania   Ing.   49
# 1467  Unie pro sport a zdraví      Bahníková Štefania   Ing.   53
# 1047  Unie pro sport a zdraví      Bahníková Štefania   Ing.   57
# 467        PRO Sport a Zdraví      Bahníková Štefania   Ing.   61
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1756              USZ                  USZ  2 320  3.27
# 1467              USZ                  USZ  2 739  2.67
# 1047              USZ                  USZ  2 038  2.40
# 467            PRO ZS                  USZ    697  2.00
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1756                       4.0    NaN  2002
# 1467                       6.0    NaN  2006
# 1047                      22.0    NaN  2010
# 467                        NaN    NaN  2014
#                               název příjmení, jméno, tituly  \
# 2236   Str.pro otevřenou společnost          Václavík David
# 1725                Strana zelených          Václavík David
# 1430                Liberec občanům          Václavík David
# 989   Starostové pro Liberecký kraj          Václavík David
#
#                  Tituly  věk Navrhujícístrana Politickápříslušnost   abs.  \
# 2236              PhDr.   27              SOS                BEZPP  3 488
# 1725        PhDr. Ph.D.   31               SZ                   SZ  4 338
# 1430   doc. PhDr. Ph.D.   35               NK                BEZPP  5 248
# 989    doc. PhDr. Ph.D.   39              SLK                BEZPP  4 897
#
#        v %  Pořadízvolení/náhradníka Mandát   Rok
# 2236  3.56                       3.0      *  2002
# 1725  3.38                       2.0      *  2006
# 1430  3.21                       4.0      *  2010
# 989   2.83                       6.0      *  2014
#                               název příjmení, jméno, tituly Tituly  věk  \
# 1819  Hn.za harm.rozvoj obcí a měst       Dostrašilová Věra    NaN   38
# 1496    SNK ED a nezávislí společně       Dostrašilová Věra    NaN   42
# 1098                   Věci veřejné       Dostrašilová Věra    NaN   46
# 554   Nový směr-společná kandidátka       Dostrašilová Věra    NaN   50
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1819            HNHRM                BEZPP    399  2.05
# 1496           SNK ED               SNK ED  1 856  2.57
# 1098               VV                   VV  2 462  2.78
# 554               NOS                  NOS    785  2.77
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1819                       NaN    NaN  2002
# 1496                      11.0    NaN  2006
# 1098                       4.0    NaN  2010
# 554                        NaN    NaN  2014
#                         název příjmení, jméno, tituly Tituly  věk  \
# 1634  Unie pro sport a zdraví           Novotný Pavel   Ing.   44
# 1310  Unie pro sport a zdraví           Novotný Pavel   Ing.   48
# 823        PRO Sport a Zdraví           Novotný Pavel   Ing.   52
# 270   Unie pro sport a zdraví           Novotný Pavel   Ing.   56
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 1634              USZ                BEZPP  2 315  2.26
# 1310              USZ                BEZPP  2 305  2.72
# 823            PRO ZS                BEZPP    910  2.61
# 270               USZ                BEZPP  1 126  2.22
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 1634                      21.0    NaN  2006
# 1310                       4.0    NaN  2010
# 823                        NaN    NaN  2014
# 270                        NaN    NaN  2018
#                                název příjmení, jméno, tituly  Tituly  věk  \
# 2264  Komunistická str.Čech a Moravy         Vondruška Josef   JUDr.   54
# 1445  Komunistická str.Čech a Moravy         Vondruška Josef   JUDr.   62
# 1010  Komunistická str.Čech a Moravy         Vondruška Josef   JUDr.   66
# 432   Komunistická str.Čech a Moravy         Vondruška Josef   JUDr.   70
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2264             KSČM                 KSČM  3 251  3.06
# 1445             KSČM                 KSČM  2 305  2.73
# 1010             KSČM                 KSČM  1 534  2.63
# 432              KSČM                 KSČM    945  2.62
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2264                       2.0      *  2002
# 1445                       3.0    NaN  2010
# 1010                      13.0    NaN  2014
# 432                        NaN    NaN  2018
#                               název příjmení, jméno, tituly Tituly  věk  \
# 2001  Křesť.demokr.unie-Čs.str.lid.         Kubín Stanislav    NaN   59
# 1595                SOS pro Liberec         Kubín Stanislav    NaN   63
# 1241                Liberec občanům         Kubín Stanislav    NaN   67
# 752             KDU-ČSL a nezávislí         Kubín Stanislav    NaN   71
#
#      Navrhujícístrana Politickápříslušnost   abs.   v %  \
# 2001          KDU-ČSL              KDU-ČSL    681  1.91
# 1595          KDU-ČSL              KDU-ČSL  5 933  2.50
# 1241          KDU-ČSL              KDU-ČSL  3 904  2.39
# 752           KDU-ČSL              KDU-ČSL    597  2.49
#
#       Pořadízvolení/náhradníka Mandát   Rok
# 2001                       NaN    NaN  2002
# 1595                      15.0    NaN  2006
# 1241                      18.0    NaN  2010
# 752                        NaN    NaN  2014

# %% [markdown]
# ### U titulů se pokuste rozlišit i různé stupně vzdělání: bakalářský, magisterský, doktorský a vyšší, vojenská hodnost atp. Zkuste odhadnout i podíl žen na kandidátkách.

# %%
data = pd.read_csv('people_data.csv', na_values=["", "-"])
df = data.loc[data.Tituly > ""]
title_summ = {
    "Bakalarsky": 0,
    "Magisterský (Mgr)": 0,
    "Docent": 0,
    "Magisterský (Ing)": 0,
    "Magisterský (jiný)": 0,
    "Doktorský": 0,
    "Profesor": 0,
             }

for title in df["Tituly"]:
    for part in title.split():
        if "Bc" in part:
            title_summ["Bakalarsky"] = title_summ["Bakalarsky"] + 1
        elif "Mgr" in part:
            title_summ["Magisterský (Mgr)"] = title_summ["Magisterský (Mgr)"] + 1
        elif "Ing" in part:
            title_summ["Magisterský (Ing)"] = title_summ["Magisterský (Ing)"] + 1
        elif part in ["Ph.D.", "DSc.", "CSc.", "Dr.", "DrSc.", "Th.D."]:
            title_summ["Doktorský"] = title_summ["Doktorský"] + 1
        elif "doc" in part:
            title_summ["Docent"] = title_summ["Docent"] + 1
        elif "prof" in part:
            title_summ["Profesor"] = title_summ["Profesor"] + 1
        else:
            title_summ["Magisterský (jiný)"] = title_summ["Magisterský (jiný)"] + 1
display(title_summ)
plt.pie(title_summ.values(),explode=(0, 0, 0, 0, 0, 0.8, 0.8), labels=title_summ.keys(), autopct="%1.1f")
plt.show()
# Out:
# {'Bakalarsky': 77,
#  'Magisterský (Mgr)': 198,
#  'Magisterský (Ing)': 445,
#  'Magisterský (jiný)': 166,
#  'Doktorský': 33,
#  'Docent': 4,
#  'Profesor': 8}
