# %% [markdown]
# # Úkol č. 1 - vizualizace dat a web scraping (do 20. října)
#
#   * V rámci tohoto úkolu musíte stáhnout dat z webu (tzv. _web scraping_, velmi základní) a následně data zpracovat a vizualizovat.
#   * Cílem bude stáhnout data ze serveru https://www.volby.cz týkající se voleb do zastupitelstva Vámi vybraného (většího) města, uložit tato data v tabulkovém formátu a pak vymyslet vizualizace a zobrazení dat, které umožní orientaci v těchto datech a zvýrazní zajímavé informace a zobrazit přehledně časový vývoj různých veličin.
#
# > **Úkoly jsou zadány tak, aby Vám daly prostor pro invenci. Vymyslet _jak přesně_ budete úkol řešit, je důležitou součástí zadání a originalita či nápaditost bude také hodnocena!**
#
# ## Výběr zdroje dat
#
# Vyberte si větší město, které má zastupitelstvo druhu 3 (Zastupitelstvo statutárního města) a strojově stáhněte informace o stranách a kandidátkách z následujících let:
#  * [2002](https://www.volby.cz/pls/kv2002/kv12?xjazyk=CZ&xid=0), [2006](https://www.volby.cz/pls/kv2006/kv12?xjazyk=CZ&xid=0), [2010](https://www.volby.cz/pls/kv2010/kv12?xjazyk=CZ&xid=0), [2014](https://www.volby.cz/pls/kv2014/kv12?xjazyk=CZ&xid=0) a [2018](https://www.volby.cz/pls/kv2018/kv12?xjazyk=CZ&xid=0).
#
#
# ## Pokyny k vypracování
#
# **Základní body zadání**, za jejichž (poctivé) vypracování získáte **8 bodů**:
#   * Strojově stáhněte data pro vybrané město a uložte je všechny do (asi dvou) přehledných tabulek ve formátu _csv_.
#   * Data musí obsahovat _alespoň_ toto:
#     * Vývoj výsledků (v procentech i počtu hlasů) pro jednotlivé strany v jednotlivých letech.
#     * Seznam všech kandidátů všech stran v jednotlivých letech, u kandidáta by mělo být zaznamenáno: jméno, věk v době voleb, navrhující strana, politická příslušnost, volební zisk (procento i počet hlasů), pořadí na kandidátce, pořadí zvolení, jestli získal mandát (tyto informace získáte souhrnně ve _jmenných seznamech_).
#   * V druhé části Vašeho Jupyter notebooku pracujte s těmito tabulkami načtenými z _csv_ souboru (aby opravující nemusel spouštět stahování z webu).
#   * Tabulky ve formátu _csv_ také odevzdejte.
#   * S využitím vybraných nástrojů zpracujte data a vymyslete vizualizace a grafy, aby bylo vidět následující:
#     * Časový vývoj (po rocích voleb) počtu kandidujících stran i lidí a to celkově i po jednotlivých stranách (ve volbách, kterých se daná strana účastnila).
#     * Věkovou strukturu kandidátů celkově i za jednotlivé strany a vývoj této struktury během jednotlivých voleb.
#     * Časový vývoj volební účasti a volebních výsledků jednotlivých stran.
#     * Časový vývoj podílu kandidujících s titulem a bez titulu.
#
# **Další body zadání** za případné další body (můžete si vybrat, maximum bodů za úkol je každopádně 12 bodů):
#   * (až +2 body) U titulů se pokuste rozlišit i různé stupně vzdělání: bakalářský, magisterský, doktorský a vyšší, vojenská hodnost atp. Zkuste odhadnout i podíl žen na kandidátkách.
#   * (až +4 body) Pokuste se u jednotlivých kandidátů zjistit, zda kandidovali ve více volbách. Najděte 10 nejpilnějších kandidátů a vypište jejich volební zisky a za jaké strany kandidovali.
#   * (až +2 body) Najděte nějaký balíček, který Vám dovolí do Vašeho notebooku zavést interaktivní prvky, např. si vyberete v select-boxu stranu a Váš notebook zobrazí grafy pouze pro ni atp.
#
# ## Poznámky k odevzdání
#
#   * Řiďte se pokyny ze stránky https://courses.fit.cvut.cz/BI-VZD/homeworks/index.html.
#   * Odevzdejte nejen Jupyter Notebook, ale i _csv_ soubor(y) se staženými daty.
#   * Opravující Vám může umožnit úkol dodělat či opravit a získat tak další body. První verze je ale důležitá a bude-li odbytá, budete za to penalizováni.

# %%
import numpy as np
import pandas as pd
import sklearn as skit
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
party_data = []
people_data = []

years = [2006, 2010, 2014, 2018]

for year in years:
    '''
        reads data from volby.cz 
    '''
    url = 'https://www.volby.cz/pls/kv' + str(year) + '/kv1111?xjazyk=CZ&xid=1&xdz=3&xnumnuts=5103&xobec=563889&xstat=0&xvyber=0'
    dfs = pd.read_html(url,flavor='html5lib')
    party_data.append(dfs[1])
    url = 'https://www.volby.cz/pls/kv' + str(year) + '/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
    dfs = pd.read_html(url,flavor='html5lib')
    #dfs[0].columns = dfs[0].comlumns.to_frame()[1]
    people_data.append(dfs[0])
    
# changes header from 2 levels to 1 level
for df in party_data:
    df.columns = df.columns.to_frame()[1]
for df in people_data:
    df.columns = df.columns.to_frame()[1]

# %%
party_data[2]
people_data[1]
# Out:
# 1    číslo                           název  poř.číslo  \
# 0        2               Změna pro Liberec         19
# 1       11    Strana Práv Občanů ZEMANOVCI         29
# 2        2               Změna pro Liberec          2
# 3        7  Demokratická regionální strana         11
# 4        9      SOS - Liberecký zastupitel         14
# 5        9      SOS - Liberecký zastupitel         35
# 6        1         Unie pro sport a zdraví         25
# 7       12                 Liberec občanům         34
# 8        2               Změna pro Liberec         16
# 9        6                    Věci veřejné         15
# 10       7  Demokratická regionální strana         22
# 11      13  Komunistická str.Čech a Moravy         17
# 12       6                    Věci veřejné          6
# 13       2               Změna pro Liberec          5
# 14       4    Suverenita-blok J.Bobošíkové          5
# 15      13  Komunistická str.Čech a Moravy         11
# 16       9      SOS - Liberecký zastupitel         17
# 17      10   Volte Pr.Blok www.cibulka.net          1
# 18      12                 Liberec občanům         10
# 19       3    Občanská demokratická strana          8
# 20      11    Strana Práv Občanů ZEMANOVCI          2
# 21       1         Unie pro sport a zdraví         30
# 22       4    Suverenita-blok J.Bobošíkové         24
# 23       7  Demokratická regionální strana         30
# 24       4    Suverenita-blok J.Bobošíkové         17
# 25       6                    Věci veřejné         16
# 26      13  Komunistická str.Čech a Moravy         21
# 27       1         Unie pro sport a zdraví         14
# 28       6                    Věci veřejné         29
# 29      12                 Liberec občanům         21
# ..     ...                             ...        ...
# 395      6                    Věci veřejné         33
# 396      6                    Věci veřejné         12
# 397      2               Změna pro Liberec         33
# 398      2               Změna pro Liberec         14
# 399      7  Demokratická regionální strana          9
# 400      4    Suverenita-blok J.Bobošíkové          8
# 401      3    Občanská demokratická strana         15
# 402     13  Komunistická str.Čech a Moravy          7
# 403      6                    Věci veřejné         35
# 404     13  Komunistická str.Čech a Moravy          6
# 405      8    Česká str.sociálně demokrat.         13
# 406      2               Změna pro Liberec         29
# 407      6                    Věci veřejné         36
# 408      6                    Věci veřejné         25
# 409      9      SOS - Liberecký zastupitel          7
# 410      3    Občanská demokratická strana         23
# 411      9      SOS - Liberecký zastupitel         27
# 412      3    Občanská demokratická strana         31
# 413      8    Česká str.sociálně demokrat.         18
# 414      1         Unie pro sport a zdraví         12
# 415      4    Suverenita-blok J.Bobošíkové         36
# 416     12                 Liberec občanům         26
# 417     13  Komunistická str.Čech a Moravy          8
# 418      3    Občanská demokratická strana         14
# 419      7  Demokratická regionální strana          2
# 420      3    Občanská demokratická strana         36
# 421      6                    Věci veřejné         14
# 422      9      SOS - Liberecký zastupitel         20
# 423     11    Strana Práv Občanů ZEMANOVCI         17
# 424      6                    Věci veřejné          8
#
# 1      příjmení, jméno, tituly  věk Navrhujícístrana Politickápříslušnost  \
# 0       Abel Daniel Tibor Ing.   46               NK                BEZPP
# 1                 Abrt Přemysl   38             SPOZ                BEZPP
# 2    Absolonová Kateřina MUDr.   44               NK                BEZPP
# 3              Andreasová Hana   27              DRS                BEZPP
# 4               Antuš Jan Mgr.   50              SOS                BEZPP
# 5               Baba Jan MVDr.   51              SOS                BEZPP
# 6      Bahníková Štefania Ing.   57              USZ                  USZ
# 7              Barthová Milena   58          KDU-ČSL                BEZPP
# 8          Barthová Petra Mgr.   39               NK                BEZPP
# 9          Bartoníček Miroslav   46               VV                   VV
# 10                  Bartoš Jan   66              DRS                  DRS
# 11         Baťka Oldřich RSDr.   63             KSČM                 KSČM
# 12               Baťová Simona   47               VV                   VV
# 13          Baxa Jaromír PhDr.   28               SZ                   SZ
# 14        Bayramová Petra Ing.   38         Suveren.                  SDŽ
# 15             Bělohlávek Jiří   60             KSČM                 KSČM
# 16      Beránek Stanislav Ing.   52              SOS                BEZPP
# 17               Beranová Jana   41               PB                BEZPP
# 18              Berki Jan Mgr.   29               NK                BEZPP
# 19           Bernát Pavel Ing.   49              ODS                  ODS
# 20               Berný Oldřich   31             SPOZ                 SPOZ
# 21               Bím Leoš Mgr.   36              USZ                BEZPP
# 22            Biňovcová Andrea   19         Suveren.                BEZPP
# 23                Bláha Štěpán   28              DRS                BEZPP
# 24              Boboková Marta   58         Suveren.                BEZPP
# 25                 Bock Julius   45               VV                BEZPP
# 26             Bodnarová Lenka   30             KSČM                BEZPP
# 27                 Boháč Karel   63              USZ                BEZPP
# 28              Borisová Marie   51               VV                BEZPP
# 29                Bošek Michal   32               NK                BEZPP
# ..                         ...  ...              ...                  ...
# 395                Víc Bohumil   56               VV                BEZPP
# 396     Vilhelmová Dagmar Mgr.   42               VV                   VV
# 397              Vimmer Ctibor   51               SZ                   SZ
# 398         Vízková Dagmar Bc.   37               NK                BEZPP
# 399            Vojáčková Radka   37              DRS                BEZPP
# 400          Vojčiniak Jan Bc.   24         Suveren.                BEZPP
# 401     Vojtíšek Vladimír Ing.   51              ODS                  ODS
# 402             Voldřich Milan   55             KSČM                 KSČM
# 403         Vondráček Miroslav   25               VV                BEZPP
# 404      Vondruška Josef JUDr.   62             KSČM                 KSČM
# 405     Vorel Lukáš Dipl.-Kfm.   33             ČSSD                 ČSSD
# 406       Vrabec Vladimír Mgr.   31               NK                BEZPP
# 407                  Vrána Jan   30               VV                   VV
# 408                 Vrána Jiří   62               VV                BEZPP
# 409     Vrána Václav pplk v.v.   67              SOS                  SOS
# 410   Vyhnisová Vladimíra Ing.   32              ODS                  ODS
# 411        Vyšohlídová Marcela   26              SOS                BEZPP
# 412          Wagnerová Václava   59              ODS                  ODS
# 413             Wildner Michal   29             ČSSD                 ČSSD
# 414          Zákoucký Vít Mgr.   32              USZ                BEZPP
# 415           Zavadilová Irena   34         Suveren.                BEZPP
# 416               Zavoral Jiří   35               NK                BEZPP
# 417          Zelinková Ludmila   63             KSČM                 KSČM
# 418            Zeman Lukáš Bc.   26              ODS                  ODS
# 419         Zeronik Pavel Mgr.   32              DRS                BEZPP
# 420           Zeroniková Lucie   32              ODS                  ODS
# 421           Zikmund Miroslav   51               VV                BEZPP
# 422              Zikmund Tomáš   42              SOS                  SOS
# 423                Žitný Luděk   44             SPOZ                 SPOZ
# 424               Žižková Jana   52               VV                   VV
#
# 1     abs.    v % Pořadízvolení/náhradníka Mandát
# 0    6 191    246                        9      -
# 1      209    224                        -      -
# 2    8 467    337                        2      *
# 3    1 140    240                        -      -
# 4    1 184    272                        -      -
# 5      783    179                        -      -
# 6    2 038    240                       22      -
# 7    3 396    208                       28      -
# 8    6 543    260                        6      -
# 9    2 182    246                       12      -
# 10     976    205                        -      -
# 11   2 154    255                       14      -
# 12   2 511    283                        3      -
# 13   7 285    290                        7      *
# 14     728    306                        -      -
# 15   2 228    264                        8      -
# 16   1 021    234                        -      -
# 17     752  10000                        -      -
# 18   4 552    278                        4      -
# 19   5 766    267                        8      *
# 20     388    415                        -      -
# 21   2 036    240                       27      -
# 22     573    241                        -      -
# 23     976    205                        -      -
# 24     609    256                        -      -
# 25   2 140    241                       13      -
# 26   2 127    252                       18      -
# 27   1 945    229                       12      -
# 28   2 036    230                       26      -
# 29   4 032    246                       15      -
# ..     ...    ...                      ...    ...
# 395  1 935    218                       30      -
# 396  2 356    266                        9      -
# 397  5 783    230                       23      -
# 398  6 445    256                        4      -
# 399  1 389    292                        -      -
# 400    688    289                        -      -
# 401  5 584    258                        7      -
# 402  2 258    268                        4      -
# 403  1 902    215                       32      -
# 404  2 305    273                        3      -
# 405  5 424    264                        6      -
# 406  6 209    247                       19      -
# 407  1 950    220                       33      -
# 408  2 187    247                       22      -
# 409  1 066    244                        -      -
# 410  5 576    258                       15      -
# 411    934    214                        -      -
# 412  5 254    243                       23      -
# 413  5 269    257                       11      -
# 414  2 194    259                       10      -
# 415    527    221                        -      -
# 416  3 897    238                       20      -
# 417  2 210    262                        5      -
# 418  5 610    259                        6      -
# 419  1 608    338                        -      -
# 420  5 077    235                       28      -
# 421  2 284    258                       11      -
# 422    926    212                        -      -
# 423    244    261                        -      -
# 424  2 403    271                        5      -
#
# [425 rows x 11 columns]

# %%
type(dfs)
# Out:
# list

# %%
url = 'http://www.volby.cz/pls/kv2002/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
people_data_2002 = pd.read_html(url, displayed_only=False)
people_data_2002[0].columns = party_data_2002[0].columns.to_frame()[1]
party_data_2002
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-0b2bacb63b70> in <module>
#       1 url = 'http://www.volby.cz/pls/kv2002/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
#       2 people_data_2002 = pd.read_html(url, displayed_only=False)
# ----> 3 people_data_2002.columns = people_data_2002.columns.to_frame()
#       4 dfs
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
url = 'http://www.volby.cz/pls/kv2002/kv1211?xjazyk=CZ&xid=1&xv=1&xdz=3&xnumnuts=5103'
party_data_2002 = pd.read_html(url, displayed_only=False)
party_data_2002[0].columns = party_data_2002[0].columns.to_frame()[1]
party_data_2002
# Out:
# [1  Počet  Zpr.    v %  celkem  zvolená Zapsanívoliči Vydanéobálky  \
#  0     80    80  100.0       1        1        80 036       27 924
#
#  1  Vol.účastv % Odevzd.obálky Platnéhlasy
#  0         34.89        27 890     985 284  ,
#                                         Volební strana    Hlasy         \
#                                         Volební strana     abs.    v %
#  0   Křesťanská a demokratická unie - Československ...   35 474   3.60
#  1                  Česká strana sociálně demokratická  155 273  15.76
#  2                   Komunistická strana Čech a Moravy  105 909  10.75
#  3                        Občanská demokratická strana  273 081  27.72
#  4                                           NEZÁVISLÍ   50 781   5.15
#  5   Pravý Blok-strana za ODVOLAT.politiků, NÍZKÉ d...    2 874   0.29
#  6                    Unie svobody - Demokratická unie   53 994   5.48
#  7                     Strana pro otevřenou společnost   97 869   9.93
#  8                      Demokratická regionální strana   60 223   6.11
#  9   Hnutí nezávislých za harmonický rozvoj obcí a ...   19 386   1.97
#  10                                    Volba pro město   42 205   4.28
#  11                            Unie pro sport a zdraví   70 812   7.19
#  12                       Republikáni Miroslava Sládka    1 465   0.15
#  13                           Strana svobodných severu    3 527   0.36
#  14                       Strana občanského porozumění    3 370   0.34
#  15                                             Naděje    9 041   0.92
#
#     Zastupitelé
#            abs.    v %
#  0            0   0.00
#  1            7  17.95
#  2            5  12.82
#  3           13  33.33
#  4            2   5.13
#  5            0   0.00
#  6            2   5.13
#  7            4  10.26
#  8            3   7.69
#  9            0   0.00
#  10           0   0.00
#  11           3   7.69
#  12           0   0.00
#  13           0   0.00
#  14           0   0.00
#  15           0   0.00  ,
#                                                     0
#  0  Výsledky dle navrhujících stran Výsledky dle p...]

# %%
pd.DataFrame(party_data).to_csv("party_data.csv")
pd.DataFrame(people_data).to_csv("people_data.csv")

# %%
pd.DataFrame(party_data[0]).info()
pd.DataFrame(people_data[0]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
# (Kandidátní listina, číslo)                                                 10 non-null int64
# (Kandidátní listina, název)                                                 10 non-null object
# (Hlasy, abs.)                                                               10 non-null object
# (Hlasy, v %)                                                                10 non-null int64
# (Početkandidátů, Početkandidátů)                                            10 non-null int64
# (Přepočtenýzákladdle počtukandidátů, Přepočtenýzákladdle počtukandidátů)    10 non-null object
# (Přepočtené %platných hlasů, Přepočtené %platných hlasů)                    10 non-null int64
# (Početmandátů, Početmandátů)                                                10 non-null int64
# (Podílyhlasů, Podílyhlasů)                                                  10 non-null object
# dtypes: int64(5), object(4)
# memory usage: 800.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
# (Kandidátní listina, číslo)                             287 non-null int64
# (Kandidátní listina, název)                             287 non-null object
# (Kandidát, poř.číslo)                                   287 non-null int64
# (Kandidát, příjmení, jméno, tituly)                     287 non-null object
# (Kandidát, věk)                                         287 non-null int64
# (Navrhujícístrana, Navrhujícístrana)                    287 non-null object
# (Politickápříslušnost, Politickápříslušnost)            287 non-null object
# (Hlasy, abs.)                                           287 non-null object
# (Hlasy, v %)                                            287 non-null int64
# (Pořadízvolení/náhradníka, Pořadízvolení/náhradníka)    287 non-null object
# (Mandát, Mandát)                                        287 non-null object
# dtypes: int64(4), object(7)
# memory usage: 24.7+ KB
