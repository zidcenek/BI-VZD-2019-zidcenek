# %% [markdown]
# # Úkol č. 1 - vizualizace dat a web scraping (do 20. října)
#
#   * V rámci tohoto úkolu musíte stáhnout dat z webu (tzv. _web scraping_, velmi základní) a následně data zpracovat a vizualizovat.
#   * Cílem bude stáhnout data ze serveru https://www.volby.cz týkající se voleb do zastupitelstva Vámi vybraného (většího) města, uložit tato data v tabulkovém formátu a pak vymyslet vizualizace a zobrazení dat, které umožní orientaci v těchto datech a zvýrazní zajímavé informace a zobrazit přehledně časový vývoj různých veličin.
#
# > **Úkoly jsou zadány tak, aby Vám daly prostor pro invenci. Vymyslet _jak přesně_ budete úkol řešit, je důležitou součástí zadání a originalita či nápaditost bude také hodnocena!**
#
# ## Výběr zdroje dat
#
# Vyberte si větší město, které má zastupitelstvo druhu 3 (Zastupitelstvo statutárního města) a strojově stáhněte informace o stranách a kandidátkách z následujících let:
#  * [2002](https://www.volby.cz/pls/kv2002/kv12?xjazyk=CZ&xid=0), [2006](https://www.volby.cz/pls/kv2006/kv12?xjazyk=CZ&xid=0), [2010](https://www.volby.cz/pls/kv2010/kv12?xjazyk=CZ&xid=0), [2014](https://www.volby.cz/pls/kv2014/kv12?xjazyk=CZ&xid=0) a [2018](https://www.volby.cz/pls/kv2018/kv12?xjazyk=CZ&xid=0).
#
#
# ## Pokyny k vypracování
#
# **Základní body zadání**, za jejichž (poctivé) vypracování získáte **8 bodů**:
#   * Strojově stáhněte data pro vybrané město a uložte je všechny do (asi dvou) přehledných tabulek ve formátu _csv_.
#   * Data musí obsahovat _alespoň_ toto:
#     * Vývoj výsledků (v procentech i počtu hlasů) pro jednotlivé strany v jednotlivých letech.
#     * Seznam všech kandidátů všech stran v jednotlivých letech, u kandidáta by mělo být zaznamenáno: jméno, věk v době voleb, navrhující strana, politická příslušnost, volební zisk (procento i počet hlasů), pořadí na kandidátce, pořadí zvolení, jestli získal mandát (tyto informace získáte souhrnně ve _jmenných seznamech_).
#   * V druhé části Vašeho Jupyter notebooku pracujte s těmito tabulkami načtenými z _csv_ souboru (aby opravující nemusel spouštět stahování z webu).
#   * Tabulky ve formátu _csv_ také odevzdejte.
#   * S využitím vybraných nástrojů zpracujte data a vymyslete vizualizace a grafy, aby bylo vidět následující:
#     * Časový vývoj (po rocích voleb) počtu kandidujících stran i lidí a to celkově i po jednotlivých stranách (ve volbách, kterých se daná strana účastnila).
#     * Věkovou strukturu kandidátů celkově i za jednotlivé strany a vývoj této struktury během jednotlivých voleb.
#     * Časový vývoj volební účasti a volebních výsledků jednotlivých stran.
#     * Časový vývoj podílu kandidujících s titulem a bez titulu.
#
# **Další body zadání** za případné další body (můžete si vybrat, maximum bodů za úkol je každopádně 12 bodů):
#   * (až +2 body) U titulů se pokuste rozlišit i různé stupně vzdělání: bakalářský, magisterský, doktorský a vyšší, vojenská hodnost atp. Zkuste odhadnout i podíl žen na kandidátkách.
#   * (až +4 body) Pokuste se u jednotlivých kandidátů zjistit, zda kandidovali ve více volbách. Najděte 10 nejpilnějších kandidátů a vypište jejich volební zisky a za jaké strany kandidovali.
#   * (až +2 body) Najděte nějaký balíček, který Vám dovolí do Vašeho notebooku zavést interaktivní prvky, např. si vyberete v select-boxu stranu a Váš notebook zobrazí grafy pouze pro ni atp.
#
# ## Poznámky k odevzdání
#
#   * Řiďte se pokyny ze stránky https://courses.fit.cvut.cz/BI-VZD/homeworks/index.html.
#   * Odevzdejte nejen Jupyter Notebook, ale i _csv_ soubor(y) se staženými daty.
#   * Opravující Vám může umožnit úkol dodělat či opravit a získat tak další body. První verze je ale důležitá a bude-li odbytá, budete za to penalizováni.

# %%
import numpy as np
import pandas as pd
import sklearn as skit
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
party_data = []
people_data = []

years = [2006, 2010, 2014, 2018]

for year in years:
    '''
        reads data from volby.cz 
    '''
    url = 'https://www.volby.cz/pls/kv' + str(year) + '/kv1111?xjazyk=CZ&xid=1&xdz=3&xnumnuts=5103&xobec=563889&xstat=0&xvyber=0'
    dfs = pd.read_html(url,flavor='html5lib')
    party_data.append(dfs[1])
    url = 'https://www.volby.cz/pls/kv' + str(year) + '/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
    dfs = pd.read_html(url,flavor='html5lib')
    #dfs[0].columns = dfs[0].comlumns.to_frame()[1]
    people_data.append(dfs[0])
    
# changes header from 2 levels to 1 level
for df in party_data:
    df.columns = df.columns.to_frame()[1]
for df in people_data:
    df.columns = df.columns.to_frame()[1]

# %%
# Řešení titulů pro roky 2006 - 2018
# Rozpoznávaé tituly
titles = ["Bc.", "BcA.", "Ing.", "Ing. arch.", "MUDr.", "MVDr.", "Mgr.", "MgA.", "JUDr.", "PhDr.", "RNDr.", "PharmDr.", "ThLic.", "ThDr.", "Ph.D.", "Ph.D.", "Th.D.", "CSc.", "DrSc.", "doc.", "prof."]

for df in people_data:
    title_frame = []
    cols = list(df)
    cols.insert(4, "Tituly")
    df["Tituly"] = np.nan
    df.columns = cols
    for index, row in df.iterrows():
        arr = row["příjmení, jméno, tituly"].split()
        title = ""
        if len(arr) < 3:
            title_frame.append("")
            continue
        for name in arr:
            if name in titles: 
                title = title + " " + name
        title_frame.append(title)
    df["Tituly"] = title_frame

# %%
people_data[3]
# Out:
#      číslo                           název  poř.číslo  \
# 0       10               Změna pro Liberec         10
# 1        5                        ANO 2011          3
# 2        7  PRO 2016 s podporou Svobodných         19
# 3        8                   Liberec Plus+         37
# 4       12    Česká str.sociálně demokrat.         28
# 5        8                   Liberec Plus+          5
# 6        5                        ANO 2011         26
# 7        2  Svob.a př.dem.-T.Okamura (SPD)          8
# 8        2  Svob.a př.dem.-T.Okamura (SPD)         38
# 9       12    Česká str.sociálně demokrat.         35
# 10       3   Starostové pro Liberecký kraj         35
# 11       6   Liberec otevřený lidem - LOL!         31
# 12       6   Liberec otevřený lidem - LOL!          5
# 13       7  PRO 2016 s podporou Svobodných          1
# 14       6   Liberec otevřený lidem - LOL!          1
# 15       2  Svob.a př.dem.-T.Okamura (SPD)         16
# 16       6   Liberec otevřený lidem - LOL!         26
# 17       9  Komunistická str.Čech a Moravy         22
# 18       7  PRO 2016 s podporou Svobodných          7
# 19      10               Změna pro Liberec         24
# 20      11           Strana soukromníků ČR         12
# 21       1         Unie pro sport a zdraví          8
# 22       3   Starostové pro Liberecký kraj          5
# 23      12    Česká str.sociálně demokrat.         23
# 24       8                   Liberec Plus+         10
# 25       3   Starostové pro Liberecký kraj         24
# 26       8                   Liberec Plus+         28
# 27       5                        ANO 2011         37
# 28       2  Svob.a př.dem.-T.Okamura (SPD)         32
# 29       7  PRO 2016 s podporou Svobodných         32
# ..     ...                             ...        ...
# 433      6   Liberec otevřený lidem - LOL!          9
# 434      2  Svob.a př.dem.-T.Okamura (SPD)          3
# 435      9  Komunistická str.Čech a Moravy         33
# 436      6   Liberec otevřený lidem - LOL!         39
# 437     10               Změna pro Liberec         13
# 438     11           Strana soukromníků ČR         16
# 439      3   Starostové pro Liberecký kraj         17
# 440      6   Liberec otevřený lidem - LOL!          6
# 441      2  Svob.a př.dem.-T.Okamura (SPD)         28
# 442     11           Strana soukromníků ČR         34
# 443      6   Liberec otevřený lidem - LOL!         33
# 444      7  PRO 2016 s podporou Svobodných         22
# 445      2  Svob.a př.dem.-T.Okamura (SPD)         29
# 446      5                        ANO 2011         23
# 447      7  PRO 2016 s podporou Svobodných         18
# 448      3   Starostové pro Liberecký kraj          1
# 449      3   Starostové pro Liberecký kraj         14
# 450     12    Česká str.sociálně demokrat.         31
# 451      5                        ANO 2011         11
# 452      7  PRO 2016 s podporou Svobodných         36
# 453      2  Svob.a př.dem.-T.Okamura (SPD)         26
# 454      1         Unie pro sport a zdraví         12
# 455      7  PRO 2016 s podporou Svobodných         30
# 456     11           Strana soukromníků ČR          8
# 457      9  Komunistická str.Čech a Moravy         14
# 458     12    Česká str.sociálně demokrat.         18
# 459      3   Starostové pro Liberecký kraj         10
# 460      7  PRO 2016 s podporou Svobodných         25
# 461      4    Občanská demokratická strana          1
# 462      4    Občanská demokratická strana         12
#
#               příjmení, jméno, tituly        Tituly          věk  \
# 0           Absolonová Kateřina MUDr.         MUDr.       Zelení
# 1                Balašová Renáta Mgr.          Mgr.          ANO
# 2                      Ballaty Daniel                   Svobodní
# 3                          Bára Milan                         NK
# 4                    Bartáková Milada                       ČSSD
# 5                   Bartoň Zdeněk Bc.           Bc.           NK
# 6               Bartoníčková Veronika                        ANO
# 7                          Bartoš Jan                        SPD
# 8                  Bartošová Veronika                        SPD
# 9               Bartošová Zuzana Ing.          Ing.         ČSSD
# 10               Bartůšek Ondřej Mgr.          Mgr.          SLK
# 11                       Basl Vojtěch                         NK
# 12              Baslová Petra Alžběta                        TJ.
# 13                    Batthyány Tibor                    PRO2016
# 14           Baxa Jaromír PhDr. Ph.D.   PhDr. Ph.D.          TJ.
# 15                     Beck Vlastimil                        SPD
# 16   Beckert Michal Dipl.-Übers. (FH)                         NK
# 17                    Bělohlávek Jiří                       KSČM
# 18                       Benek Martin                   Svobodní
# 19                Benešová Radka Mgr.          Mgr.       Zelení
# 20                         Berčo Jiří                Soukromníci
# 21                       Berka Martin                        USZ
# 22               Berki Jan Mgr. Ph.D.    Mgr. Ph.D.          SLK
# 23                    Bernášek Zdeněk                       ČSSD
# 24                     Bezucha Michal                        NOS
# 25                      Bílková Iveta                        SLK
# 26                     Bitterlich Jan                         NK
# 27                         Bláha Jiří                        ANO
# 28                     Boček Alexandr                        SPD
# 29                     Borkovec Lukáš                    PRO2016
# ..                                ...           ...          ...
# 433                  Vorel Filip Mgr.          Mgr.           NK
# 434             Vostenak John Bc. MBA           Bc.          SPD
# 435                  Votoček Jaroslav                       KSČM
# 436                       Votruba Jan                         NK
# 437              Vrabec Vladimír Mgr.          Mgr.       Zelení
# 438                    Vrba Jan JUDr.         JUDr.  Soukromníci
# 439                Vytiska Jakub Ing.          Ing.          SLK
# 440                Vytiska Jiří MUDr.         MUDr.           NK
# 441                 Wallach František                        SPD
# 442            Wasylyszynová Kateřina                Soukromníci
# 443                        Weiss Emil                         NK
# 444                  Wernerová Libuše                    PRO2016
# 445                    Záhumenský Jan                        SPD
# 446                 Zákoucký Vít Mgr.          Mgr.          ANO
# 447                     Záleský Jakub                    PRO2016
# 448       Zámečník Jaroslav Ing. CSc.     Ing. CSc.          SLK
# 449                  Zavoral Jiří Bc.           Bc.          SLK
# 450                  Zavřelová Denisa                       ČSSD
# 451           Zdráhala Petr Ing. Mgr.     Ing. Mgr.          ANO
# 452              Zdvihalová Miroslava                    PRO2016
# 453                    Zedníček Milan                        SPD
# 454            Zelenka Milan PharmDr.      PharmDr.          USZ
# 455                        Zeler Aleš                    PRO2016
# 456                    Zelinka Martin                Soukromníci
# 457                 Zelinková Ludmila                       KSČM
# 458                       Zeman Marek                       ČSSD
# 459                     Zemanová Hana                        SLK
# 460                     Zikmund Tomáš                   Svobodní
# 461               Židek Petr Mgr. MPA          Mgr.          ODS
# 462            Židková Lucie Mgr. MBA          Mgr.          ODS
#
#     Navrhujícístrana Politickápříslušnost  abs. v % Pořadízvolení/náhradníka  \
# 0              BEZPP                4 332   274   4                        -
# 1              BEZPP                6 865   270   3                        *
# 2           Svobodní                1 043   244   -                        -
# 3              BEZPP                  357   191   -                        -
# 4               ČSSD                  591   234   -                        -
# 5              BEZPP                  532   285   -                        -
# 6              BEZPP                6 432   253  15                        -
# 7                SPD                1 424   261   -                        -
# 8              BEZPP                1 264   231   -                        -
# 9               ČSSD                  561   222   -                        -
# 10             BEZPP                9 181   240  19                        -
# 11             BEZPP                1 387   221  29                        -
# 12             BEZPP                1 862   297   3                        -
# 13           PRO2016                2 276   533   -                        -
# 14            Zelení                2 820   449   2                        *
# 15               SPD                1 390   254   -                        -
# 16             BEZPP                1 442   230  24                        -
# 17              KSČM                  917   254   -                        -
# 18          Svobodní                1 097   257   -                        -
# 19            Zelení                3 933   249  18                        -
# 20       Soukromníci                  157   285   -                        -
# 21             BEZPP                1 357   268   -                        -
# 22               SLK               10 508   275   5                        *
# 23              ČSSD                  607   240   -                        -
# 24               NOS                  440   236   -                        -
# 25             BEZPP                9 612   251   8                        -
# 26             BEZPP                  393   211   -                        -
# 27             BEZPP                6 104   240  26                        -
# 28               SPD                1 352   247   -                        -
# 29             BEZPP                1 013   237   -                        -
# ..               ...                  ...   ...  ..                      ...
# 433            BEZPP                1 727   275   7                        -
# 434              SPD                1 482   271   -                        -
# 435            BEZPP                  868   241   -                        -
# 436            BEZPP                1 174   187  37                        -
# 437           Zelení                4 113   260   7                        -
# 438            BEZPP                  231   420   -                        -
# 439            BEZPP                9 804   256   1                        -
# 440            BEZPP                2 280   363   1                        -
# 441              SPD                1 354   248   -                        -
# 442            BEZPP                  127   231   -                        -
# 443            BEZPP                1 338   213  31                        -
# 444            BEZPP                1 027   240   -                        -
# 445              SPD                1 358   248   -                        -
# 446            BEZPP                6 615   260  12                        -
# 447            BEZPP                1 038   243   -                        -
# 448              SLK               10 825   283   3                        *
# 449            BEZPP                9 850   258  14                        *
# 450            BEZPP                  590   234   -                        -
# 451              ANO                6 718   264  11                        *
# 452            BEZPP                1 001   234   -                        -
# 453              SPD                1 362   249   -                        -
# 454            BEZPP                1 326   262   -                        -
# 455            BEZPP                1 033   242   -                        -
# 456      Soukromníci                  169   307   -                        -
# 457             KSČM                  929   258   -                        -
# 458             ČSSD                  646   256   -                        -
# 459          KDU-ČSL                9 959   260  10                        *
# 460            BEZPP                1 046   245   -                        -
# 461              ODS                2 983   299   1                        *
# 462              ODS                2 730   274   8                        -
#
#      Mandát
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ..      ...
# 433     NaN
# 434     NaN
# 435     NaN
# 436     NaN
# 437     NaN
# 438     NaN
# 439     NaN
# 440     NaN
# 441     NaN
# 442     NaN
# 443     NaN
# 444     NaN
# 445     NaN
# 446     NaN
# 447     NaN
# 448     NaN
# 449     NaN
# 450     NaN
# 451     NaN
# 452     NaN
# 453     NaN
# 454     NaN
# 455     NaN
# 456     NaN
# 457     NaN
# 458     NaN
# 459     NaN
# 460     NaN
# 461     NaN
# 462     NaN
#
# [463 rows x 12 columns]

# %%
party_data[2]
# Out:
# 1   číslo                           název     abs.   v %  Početkandidátů  \
# 0       1   Nový směr-společná kandidátka   28 259   271              39
# 1       2    Česká str.sociálně demokrat.  102 429   982              39
# 2       3   Starostové pro Liberecký kraj  172 933  1659              39
# 3       4               Změna pro Liberec  265 450  2546              39
# 4       5          Úsvit přímé demokracie   14 479   139              39
# 5       6             KDU-ČSL a nezávislí   23 964   230              39
# 6       7    Str.pro otevřenou společnost    6 044    58              36
# 7       8                          TOP 09   56 952   546              39
# 8       9              Liberec ještě žije   16 293   156              39
# 9      10        Strana svobodných občanů   19 909   191              39
# 10     11  Komunistická str.Čech a Moravy   58 283   559              39
# 11     12    Občanská demokratická strana   52 598   504              39
# 12     13                        ANO 2011  188 225  1805              39
# 13     14              Strana Práv Občanů    2 016    19              35
# 14     15              PRO Sport a Zdraví   34 841   334              39
#
# 1  Přepočtenýzákladdle počtukandidátů  Přepočtené %platných hlasů  \
# 0                        1 042 675,00                         271
# 1                        1 042 675,00                         982
# 2                        1 042 675,00                        1658
# 3                        1 042 675,00                        2545
# 4                        1 042 675,00                         138
# 5                        1 042 675,00                         229
# 6                          962 469,23                          62
# 7                        1 042 675,00                         546
# 8                        1 042 675,00                         156
# 9                        1 042 675,00                         190
# 10                       1 042 675,00                         558
# 11                       1 042 675,00                         504
# 12                       1 042 675,00                        1805
# 13                         935 733,97                          21
# 14                       1 042 675,00                         334
#
# 1   Početmandátů Podílyhlasů
# 0              0           -
# 1              4           X
# 2              8           X
# 3             12           X
# 4              0           -
# 5              0           -
# 6              0           -
# 7              2           X
# 8              0           -
# 9              0           -
# 10             2           X
# 11             2           X
# 12             9           X
# 13             0           -
# 14             0           -

# %%
# reads people data for year 2002
url = 'http://www.volby.cz/pls/kv2002/kv21111?xjazyk=CZ&xid=1&xv=11&xdz=3&xnumnuts=5103&xobec=563889&xstrana=0'
people_data_2002 = pd.read_html(url, displayed_only=False)
people_data_2002[0].columns = people_data_2002[0].columns.to_frame()[1]

# %%
display(people_data_2002[0].columns)
display(people_data[0].columns)
# Out:
# Index(['Kandidátnílistina', 'Kandidátnílistina.1', 'Poř.číslo',
#        'Příjmení, jméno', 'Tituly', 'Věk', 'Navrh.strana', 'Polit.přísl.',
#        'abs.', 'v %', 'Pořadí', 'Mandát'],
#       dtype='object', name=1)
# Index(['číslo', 'název', 'poř.číslo', 'příjmení, jméno, tituly', 'Tituly',
#        'věk', 'Navrhujícístrana', 'Politickápříslušnost', 'abs.', 'v %',
#        'Pořadízvolení/náhradníka', 'Mandát'],
#       dtype='object')

# %%
# reads party data for year 2002
url = 'http://www.volby.cz/pls/kv2002/kv1211?xjazyk=CZ&xid=1&xv=1&xdz=3&xnumnuts=5103'
party_data_2002 = pd.read_html(url, displayed_only=False)
party_data_2002[0].columns = party_data_2002[0].columns.to_frame()[1]
party_data_2002[1].columns = party_data_2002[1].columns.to_frame()[1]

# %%
# data from 2002 append other data
people_data_2002[0].columns = people_data[0].columns
people_data.append(people_data_2002[0])

# %%
for index, df in enumerate(party_data): 
    print("asdasd")
    df = df.drop(columns = ["číslo", "Početkandidátů", "Přepočtenýzákladdle počtukandidátů", "Podílyhlasů"])
#party_data[0].drop(columns = ["číslo", "Početkandidátů", "Přepočtenýzákladdle počtukandidátů", "Podílyhlasů"])
# Out:
# asdasd
# asdasd
# asdasd
# asdasd
# 1                           název     abs.   v %  Přepočtené %platných hlasů  \
# 0     SNK ED a nezávislí společně   72 106   639                         638
# 1                 Strana zelených  127 974  1133                        1133
# 2    Občanská demokratická strana  326 189  2889                        2888
# 3         Unie pro sport a zdraví  102 316   906                         906
# 4  NEZ.DEMOKRATÉ(předs.V.Železný)    1 929    17                          74
# 5    Česká str.sociálně demokrat.  161 564  1431                        1430
# 6  Komunistická str.Čech a Moravy   98 964   876                         876
# 7                 SOS pro Liberec  236 848  2098                        2152
# 8   Koruna Česká (monarch.strana)      776     7                          67
# 9   Občanská demokratická aliance      454     4                          78
#
# 1  Početmandátů
# 0             2
# 1             4
# 2            12
# 3             3
# 4             0
# 5             6
# 6             3
# 7             9
# 8             0
# 9             0

# %%
display(party_data_2002[1])
display(party_data[0])
# Out:
# 1                                      Volební strana     abs.    v %  abs.  \
# 0   Křesťanská a demokratická unie - Československ...   35 474   3.60     0
# 1                  Česká strana sociálně demokratická  155 273  15.76     7
# 2                   Komunistická strana Čech a Moravy  105 909  10.75     5
# 3                        Občanská demokratická strana  273 081  27.72    13
# 4                                           NEZÁVISLÍ   50 781   5.15     2
# 5   Pravý Blok-strana za ODVOLAT.politiků, NÍZKÉ d...    2 874   0.29     0
# 6                    Unie svobody - Demokratická unie   53 994   5.48     2
# 7                     Strana pro otevřenou společnost   97 869   9.93     4
# 8                      Demokratická regionální strana   60 223   6.11     3
# 9   Hnutí nezávislých za harmonický rozvoj obcí a ...   19 386   1.97     0
# 10                                    Volba pro město   42 205   4.28     0
# 11                            Unie pro sport a zdraví   70 812   7.19     3
# 12                       Republikáni Miroslava Sládka    1 465   0.15     0
# 13                           Strana svobodných severu    3 527   0.36     0
# 14                       Strana občanského porozumění    3 370   0.34     0
# 15                                             Naděje    9 041   0.92     0
#
# 1     v %
# 0    0.00
# 1   17.95
# 2   12.82
# 3   33.33
# 4    5.13
# 5    0.00
# 6    5.13
# 7   10.26
# 8    7.69
# 9    0.00
# 10   0.00
# 11   7.69
# 12   0.00
# 13   0.00
# 14   0.00
# 15   0.00
# 1  číslo                           název     abs.   v %  Početkandidátů  \
# 0      1     SNK ED a nezávislí společně   72 106   639              39
# 1      2                 Strana zelených  127 974  1133              39
# 2      3    Občanská demokratická strana  326 189  2889              39
# 3      4         Unie pro sport a zdraví  102 316   906              39
# 4      5  NEZ.DEMOKRATÉ(předs.V.Železný)    1 929    17               9
# 5      6    Česká str.sociálně demokrat.  161 564  1431              39
# 6      7  Komunistická str.Čech a Moravy   98 964   876              39
# 7      8                 SOS pro Liberec  236 848  2098              38
# 8      9   Koruna Česká (monarch.strana)      776     7               4
# 9     10   Občanská demokratická aliance      454     4               2
#
# 1 Přepočtenýzákladdle počtukandidátů  Přepočtené %platných hlasů  \
# 0                       1 129 120,00                         638
# 1                       1 129 120,00                        1133
# 2                       1 129 120,00                        2888
# 3                       1 129 120,00                         906
# 4                         260 566,15                          74
# 5                       1 129 120,00                        1430
# 6                       1 129 120,00                         876
# 7                       1 100 168,20                        2152
# 8                         115 807,17                          67
# 9                          57 903,58                          78
#
# 1  Početmandátů Podílyhlasů
# 0             2           X
# 1             4           X
# 2            12           X
# 3             3           X
# 4             0           -
# 5             6           X
# 6             3           X
# 7             9           X
# 8             0           -
# 9             0           -

# %%
pd.DataFrame(party_data).to_csv("party_data.csv")
pd.DataFrame(people_data).to_csv("people_data.csv")

# %%
pd.DataFrame(party_data[0]).info()
pd.DataFrame(people_data[0]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
# číslo                                 10 non-null int64
# název                                 10 non-null object
# abs.                                  10 non-null object
# v %                                   10 non-null int64
# Početkandidátů                        10 non-null int64
# Přepočtenýzákladdle počtukandidátů    10 non-null object
# Přepočtené %platných hlasů            10 non-null int64
# Početmandátů                          10 non-null int64
# Podílyhlasů                           10 non-null object
# dtypes: int64(5), object(4)
# memory usage: 800.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 12 columns):
# číslo                       287 non-null int64
# název                       287 non-null object
# poř.číslo                   287 non-null int64
# příjmení, jméno, tituly     287 non-null object
# Tituly                      287 non-null object
# věk                         287 non-null object
# Navrhujícístrana            287 non-null object
# Politickápříslušnost        287 non-null object
# abs.                        287 non-null int64
# v %                         287 non-null object
# Pořadízvolení/náhradníka    287 non-null object
# Mandát                      0 non-null float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.0+ KB
